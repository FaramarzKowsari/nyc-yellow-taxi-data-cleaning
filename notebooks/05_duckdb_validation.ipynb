# %% [markdown]
# # 05 - Independent validation with DuckDB

# %%
import sys
sys.path.insert(0,'src')
from duckdb_validation import validate
validate('data/processed/sample_cleaned_polars.parquet')

# %% [markdown]
# The validator fails the process if hard-invalid rows, non-positive durations, invalid zones, or exact duplicates survive.
