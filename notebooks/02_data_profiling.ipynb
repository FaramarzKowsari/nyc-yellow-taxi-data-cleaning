# %% [markdown]
# # 02 - Data profiling

# %%
import pandas as pd
path='data/sample/yellow_taxi_dirty_sample.parquet'
df=pd.read_parquet(path)
df.head()

# %%
profile = pd.DataFrame({'dtype':df.dtypes.astype(str),'missing':df.isna().sum(),'unique':df.nunique(dropna=False)})
profile

# %%
{'rows':len(df),'columns':df.shape[1],'exact_duplicates':int(df.duplicated().sum())}
