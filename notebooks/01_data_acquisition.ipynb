# %% [markdown]
# # 01 - Data acquisition and provenance

# %% [markdown]
# This notebook documents the official TLC source, downloads the January 2025 Yellow Taxi Parquet file, and records SHA-256 metadata.

# %%
from pathlib import Path
from src.download_data import DEFAULT_URL
print(DEFAULT_URL)

# %%
# Run from the repository root when internet access is available:
# !python src/download_data.py
